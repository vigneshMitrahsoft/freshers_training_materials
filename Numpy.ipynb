# %% [markdown]
# **NumPy:**
#   * NumPy stands for Numerical Python
#   * It was introduced by 2005 by Travis Oliphant
#   * NumPy is a Python library used for working with arrays

# %% [markdown]
# **Why we use numPy in python:**
#
# * **Faster Arrays:** NumPy helps you work with large lists of numbers (arrays) more quickly and efficiently than regular Python lists.
#
# * **Easy Math:** You can easily do math on whole arrays at once, like adding or multiplying all numbers, without writing loops.
#
# * **Useful Functions**: NumPy has built-in tools for math and statistics, like finding averages or solving equations, making it great for working with data.

# %% [markdown]
# ![python_list.png](data:image/png;base64,...)

# %% [markdown]
# ![python_array.png](data:image/png;base64,...)

# %% [markdown]
# **why we use numpy instead of list :**
#
# 1. Why NumPy is Faster:
#
#   * NumPy arrays, on the other hand, are designed specifically for handling numbers. They are stored in a continuous block of memory. So, NumPy can do the same task much faster than a Python list.
# Example: If you want to add 10 to every number in a list:
#
#   * In Python, you might need to loop through each number.
# In NumPy, you can add 10 to the entire array at once, and it will be done much faster.
# 2. Why NumPy Saves Memory:
#   * Python lists can store different types of data in each position (like numbers, strings, etc.). This flexibility means it takes more memory to store the data, even if you’re only working with numbers.
# NumPy arrays only store one type of data (usually numbers) and use a special, compact format to store it. This means NumPy uses less memory to store the same amount of data, which is important when working with large datasets.
#   * Example: A Python list storing numbers uses more memory because it has to keep track of extra information (like type of data). NumPy arrays, on the other hand, are optimized to store only the numbers you need, taking up less space.

# %% [markdown]
# **What is data scienctist  use numpy:**
#   * The role of data scientist is to collecting, analyzing, and interpreting large amounts of information to find patterns, make predictions, and gain insights. Data scientists use math, statistics, and programming to turn raw data into useful knowledge for businesses, research, and more.
#   * Data scientist mostly use python as their primary language , so numpy is much faster than list for mathematical operation and numpy has inbuild statistical operations like mean, median and standard deviation and etc

# %% [markdown]
# **NumPy installation:**

# %%
pip install numpy

# %%
import numpy as np
import time

# %%
# import numpy as np
# import time

size = 100000
my_list = list(range(size))
my_array = np.arange(size)

start_time = time.time()
# print(my_list)
result_list = [x * 2 for x in my_list]
# print(result_list)
end_time = time.time()
list_time = end_time - start_time

start_time = time.time()
result_array = my_array * 2
end_time = time.time()
array_time = end_time - start_time

print("List execution time:", list_time)
print("NumPy array execution time:", array_time)

# %% [markdown]
# **Array():**
#   * array is used to create array in python
#   * **syntax:** name = numpy.array(value)
#   * value = numPy.array([10,20,30])

# %%
array = np.array([1, 2, 3, 4, 5])
print(array)
print(type(array ))    # whatever you declare inside the array func are ndarray type

# %% [markdown]
# **Dimensions in numpy:**
#   * Dimension in array defnes the number of rows in array,

# %%
array_zero = np.array(42)
array_one = np.array([10,20,30])
array_two = np.array([[10,20,30],[40,50,60]])
array_three = np.array([[10,20,30],[40,50,60],[70,80,90]])
print(array_zero)
print(array_one)
print(array_two)
print(array_three)
array_zero = np.array(42,ndmin=3)
print(array_zero)       # (array_zero.ndim)

# %% [markdown]
# **Array indexing and slicing:**
#   * It is used to access the values using the index positioning
#   * The index number is starting from 0 and ending can be accessed by length-1.
#   * array slicing is similar to slicing in python
#   * It is used to access the particular length
#   * syntax: [start_index:end_index]
#   * another method: [start:end:step]

# %%
# array = np.array([10,20,30,40])
array = np.array([[10,20,30,40],[50,60,70,80]])
print(array[0])
print(array[1:6])
print(array[1, -3:4])
print(array[1:6:2])

# %% [markdown]
# **Data types in numpy:**
#   * Data types in numpy is used to define the type of data , it is used to modify the datatypes
#   * It is used to set the suitable datatypes as the datatype for all the array
#   *

# %%
my_unicode_array = np.array(['Hello', 'नमस्ते', '你好'], dtype='S')  # 'U' stands for Unicode
print(my_unicode_array)

# %% [markdown]
# **Copy and View in numpy:**
#   * ***Copy:*** Copy in numpy is used to make copy of the value and it doesnot affect the original value ,it is used for backup the data without any crash
#   * **View:** View in numpy is like a mirror if we change in original value the value  will also change in the view variable

# %%
array = np.array([1, 2, 3, 4, 5])
copy = array.copy()
array[0] = 15

print(array)
print(copy)

# %% [markdown]
# **Numpy join:**
#   * Join in numpy is to join two or more arrays into a single array. It acts similar to Python join method
#   * It can bedone in numpy using concatenatae,

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6]])

result = np.concatenate((a, b), axis=0)
print(result)

# %%
array_1 = np.array([[1, 2], [3, 4]])
array_2 = np.array([[5, 6], [7, 8]])

array_new = np.concatenate((array_1, array_2), axis=1)
print(array_new)

# %%
arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.stack((arr1, arr2))

print(arr)

# %% [markdown]
# **Note :**Refer the  other stack function like hstack vstack,block

# %% [markdown]
# **Split in numpy:**
#   * Split in numpy is used to split the array into many as we want by using this function
#   * Joining merges multiple arrays into one and Splitting breaks one array into multiple.

# %%
arr = np.array(['n','a','v'])

newarr = np.array_split(arr, 2)

print(newarr)

# %% [markdown]
# **Numpy search:**
#   * You can search an array for a certain value, and return the position of the value
#
#   * To search an array, use the where() function

# %%
arr = np.array([1, 2, 3, 4, 5, 4, 4])

x = np.where(arr == 4)
y = np.searchsorted(arr,[5],side='left')  # side='right'
print(x)
print(y)  # it returns the unindex bcoz it will the the specific value willl be albe to insert

# %% [markdown]
# **Numpy Sort:**
#   * Sorting is used to arrange the values in an array in some order based on the condition

# %%
arr = np.array([3, 2, 0, 1])

print(np.sort(arr))  #np.sort(arr)[::-1] for desc order

# %% [markdown]
# **Ufunc in numpy:**
#   * In NumPy, ufuncs are functions that operate element-wise on arrays. They are fundamental tools for performing mathematical, logical, and other operations efficiently on NumPy arrays.
#   * element-wise means executed one by one at a  time

# %% [markdown]
# **Why we use ufunc:**
#   * Fast Execution:
#     * Ufuncs are written in C, which is a lower-level language. This makes them much faster than using normal Python loops to process arrays.
#   * Vectorization:
#     * Ufuncs apply operations to entire arrays at once, which is called vectorization. This removes the need for explicit loops, which can be slow in Python.

# %% [markdown]
# **How to create ufunc:**
#   * To create your own ufunc, you have to define a function, like you do with normal functions in Python, then you add it to your NumPy ufunc library with the frompyfunc() method.
#
#   * The frompyfunc() method takes the following arguments:
#
#       * function - the name of the function.
#       * inputs - the number of input arguments (arrays).
#       * outputs - the number of output arrays.

# %%
def myadd(x):
  print(x)
  return 1

myadd = np.frompyfunc(myadd,1,1)

print(myadd([1, 2, 3, 4]))

# %% [markdown]
# **Arithmetic operation using inbuild ufunc:**

# %%
arr1 = np.array([10, 11, 12, 13, 14, 15])
arr2 = np.array([20, 21, 22, 23, 24, 25])

newarr = np.add(arr1, arr2)
newarr1 = np.subtract(arr1, arr2)
newarr2 = np.multiply(arr1, arr2)
newarr3 = np.divide(arr1, arr2)

print(newarr)
print(newarr1)
print(newarr2)
print(newarr3)

# %% [markdown]
# **Note:** Refer about the mod reminder,rounding decimal values

# %% [markdown]
# **Numpy statistical functions:**
#   * Numpy offers a inbuild statistical functions perform to get a quick results
#   * The most commonly used statistical methods are
#     * mean()
#     * median()
#     * min()
#     * max()
#     * avg()

# %%
array = np.array([1, 2, 6, 4, 5])

mean = np.mean(array)
median = np.median(array)
avg = np.average(array)
min =np.min(array)
max = np.max(array)
print(min)
print(max)
print(mean)
print(median)
print(avg)
