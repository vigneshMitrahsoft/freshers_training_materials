# %% [markdown]
# **File Handling in python**

# %% [markdown]
# # What is File Handling:
#   * File handling refers to the process of performing operations on a file such as creating, opening, reading, writing and closing it, through a programming interface.
#   *  It involves managing the data flow between the program and the file system on the storage device, ensuring that data is handled safely and efficiently.

# %% [markdown]
# # OS Module:
#   * We need to perform os related operation by import os (import os at the beinning of the code)
#   * Os module in python is used to handle the os related operaion
#   * It is suitable for various os like windows,linux,mac etc

# %%
import os

# %% [markdown]
# # os.getcwd()
#   * os.getcwd is used to get the current working directory path
#   * eg:- It check the file directory and returns where the file located

# %%
import os
cwd = os.getcwd()
print("Current working directory:", cwd)
# Out:
# Current working directory: /content

# %% [markdown]
# ![Screenshot 2025-02-18 134402.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-18 134450.png](data:image/png;base64,...)

# %% [markdown]
# **os.chdir:**
#   * os.chdir is used to change the current directory
#   * It is used to make the directory mentioned in the chdir function is set as the  current directory

# %%
def current_path():
    print("Current working directory before")
    print(os.getcwd())
    print()
current_path()
os.chdir('./')
current_path()

# %% [markdown]
# **os.mkdir:**
#   * It is used to create a new directory in the current directory
#   * If we change the current directory using the chdir then the folder creates in the changed directory
#   * syntax :- os.mkdir(path, mode, dir_fd)

# %%
os.mkdir("tesing_dir")

# %% [markdown]
# **os.mkdirs:**
#   * It is also used to make the new directory
#   * the major difference between the mkdir is that it making directories if any intermediate directory is missing, os.makedirs() method will create them all.
#   * eg:- my valid path is ./test/test1/
#   but i give the path dir to ./sample/test/test1/
#   * Normally by using mkdir it throw error like path doesnot exist but mkdirs create a new dir and create a new directory

# %%
import os
os.makedirs("test5")

# %% [markdown]
# **os.listdir():**
#   * This method returns a list of all the files and folders present inside the specified directory. If no directory is specified then the list of files and folders inside the CWD is returned.

# %%
print(os.listdir("./sample_data"))
# Out:
# ['README.md', 'anscombe.json', 'mnist_test.csv', 'mnist_train_small.csv', 'california_housing_test.csv', 'california_housing_train.csv']

# %% [markdown]
# ![Screenshot 2025-02-18 175650.png](data:image/png;base64,...)

# %% [markdown]
# **os.remove**
#   * This method is used to delete a file path
#   * This method doesnot remove the directory and if directory is found it will raise error

# %%
os.remove("/content/sample_data/mnist_train_small.csv")

# %% [markdown]
# **os.rmdir():**
#   * It is used to remove or delete an empty directory. OSError will be raised if the specified path is not an empty directory.
#   * os.rmdir("dir_name")
#   * If it is empty it will be deleted otherwise throw error

# %% [markdown]
# **Move file to another directory:**
# * It is done by impoerting additional module called shutil
# * The shutil module in Python provides a collection of high-level file and directory operations, including copying, moving, and deleting files, as well as handling archiving (creating and extracting compressed files). It simplifies tasks related to file management and filesystem operations that would otherwise require writing more complex code.

# %%
import os
import shutil

src = 'djangocrud.xlsx'
dst_directory = 'destination_folder'
if not os.path.exists(dst_directory):             # it is used to check the directory is exist or not
    os.makedirs(dst_directory)
shutil.move(src, dst_directory)

# %% [markdown]
# ![Screenshot 2025-02-18 191725.png](data:image/png;base64,...)

# %%
import os
# print(os.name)
# print(os.uname())

# %% [markdown]
# **File opening in python:**
#   * It plays major role in file handling, we want to perform read or write operation in file,Before we need to open the file and then perform the action
#   * It can be achieved by using the function called open
#   * **Syntax:** With open(filepath,mode) as alice_name:
#   * eg: with open('sample.parquet', 'r') as file:

# %% [markdown]
# **File Modes:**
#   * Once we perform any operation, it is mandatory to mention their mode like(read,write,append etc)
#   * The file operation will be based on the file mode specified in it

# %% [markdown]
# **Mostly Used file modes in python:**
#   * **r** - Read mode is used to read the file , you can able to read the whole content written in the file
#   * **w** - Opens the file for writing. Creates a new file or truncates the existing file.
#   * **a** - Opens the file for appending data. Creates a new file if it doesn’t exist.
#   * **x** - Creates a new file. Raises an error if the file already exists.
#   * **r+** - Opens the file for both reading and writing. File must exist; otherwise, it raises an error.
#   * **w+** - Opens the file for both writing and reading. Creates a new file or truncates the existing file.
#   * **a+** - Opens the file for appending and reading. Creates a new file if it doesn’t exist.
#   * **x+** - Creates a new file for reading and writing. Raises an error if the file exists

# %% [markdown]
# **File Write:**
#   * **Syntax:**file_name.write(content)

# %%
file_write = open('testsample.txt','w')
file_write.write("hii this is testing")
# file_write.close()
# Out:
# 19

# %% [markdown]
# **Writelines:**
#   * The writelines() method is used to write multiple strings to a file.
#   * The writelines() method takes an iterable object like lists, tuple, etc. containing strings as an argument.
#   * **Syntax:**file_name.writelines(content)

# %%
file_write = open('testsample.txt','w')
list_of_string = ["navis","\t smith"]
file_write.writelines(list_of_string)
file_write.close()

# %% [markdown]
# **File Read():**
#   * **synax:**file_name.read(size)
#   * Size:if you define the size, it reads the given size of characters in the file
#   * readline is used to read the specific line not all line

# %%
file_read = open('testsample.txt','r')
readed_content = file_read.read()
print(readed_content)
file_read.close()

# %% [markdown]
# **Readline and readlines:**
#   * **Readline:**
#     * The readline() method returns one line from the file
#     * You can also specified how many bytes from the line to return, by using the size parameter
#     * **Syntax:** file.readline(size)
#   * Readlines:
#     * The readlines() method returns a list containing each line in the file as a list item
#     * Use the hint parameter to limit the number of lines returned. If the total number of bytes returned exceeds the specified number, no more lines are returned.

# %%
file_read = open('testsample.txt','r')
readed_content = file_read.read()
# readed_content = file_read.read(5)
# readed_content = file_read.readlines()
print(readed_content)
print(file_read.tell())
# file_read.close()

# %% [markdown]
# **FIle Appending:**
#   * Append means to add something to the end of an existing item, list, or file without changing the original content.
#   * For example, when you append text to a file, it adds the new text at the end of the file without removing or altering what's already there.

# %%
append_file = open('testsample.txt','a')
append_file.write("\ncontent are stored here")
append_file.close()

# %% [markdown]
# **File Seek():**
#   * The file.seek() method is used to change the file's current position or "cursor" in a file.
#   * It allows you to move to a specific byte in the file, so that you can read from or write to a particular location. (i.e., reading from or writing to arbitrary locations in the file).
#   * **Syntax:** file.seek(offset, whence)

# %%
combine_operation = open("testingwork.txt",'a+')
combine_operation.write("The combined operation works properly")
# combine_operation.seek(0)
combine_operation_words = combine_operation.read()
print(combine_operation_words)

# %% [markdown]
# **File tell():**
#   * The Python File tell() method is used to find the current position of the file cursor (or pointer) within the file.
#   * This method is mostly used in scenarios where there is a need to determine whether the file cursor is either at the beginning of the file or the ending.

# %%
file_read = open('testsample.txt','r')
print(file_read.tell())
readed_content = file_read.read()
print(readed_content)

# %% [markdown]
# **w+,r+,a+ modes:**

# %%
combine_operation = open("testingwork.txt",'a+')
combine_operation.write("The combined operation works properly")
# combine_operation.seek(0)
combine_operation_words = combine_operation.read()
print(combine_operation_words)

# %% [markdown]
# **File.close():**
#   * In Python, the file.close() method is used to close an open file. When you open a file using open(), it is important to close it after you're done working with it to free up system resources. Closing the file ensures that any changes made to the file are saved and that the file handle is properly released.
#   * Alternatively, it is good practice to use the with statement to automatically close the file, even if an error occurs:
