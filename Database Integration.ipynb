# %% [markdown]
# # Database Integration:
#
#   * Database integration is the process of connect our application to our databases, executes sql queries, retrives and manipulates the datas
#   * Django generally uses the common relational database for integrations like Postgresql and mssql
#   * Each database has its own drivers or libraries for connecting those databases
#
#
# # Libraries for Database Connectivity:
#
#   * Postgresql:
#
#     * To interact with postgresql in our application, you will need a library that allows for database connections and query execution
#
#     * **psycopg2** is the most widely used library for PostgreSQL in Python.
#
#       * Installation:
#
#         ![image.png](data:image/png;base64,...)
#       * By using pythonic way we can fetch the data
#
#       ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Install MSSQL Driver:
#   * To connect Django with mssql, we need the django-mssql-backend package, which is a Microsoft SQL Server backend for Django
#
#   * Instaling requried package:
#
#     * **pyodbc** is a popular library for connecting to MSSQL in Python.
#
#       ![image.png](data:image/png;base64,...)
#
#     * Simply we can connect and fetch the data in a simple python file
#
#       ![image.png](data:image/png;base64,...)
#
#     * Same like above we can create models and fetch our datas via django ORMs
